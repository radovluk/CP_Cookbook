# %% [markdown]
# ## Job-Shop Scheduling Problem

# %% [markdown]
# This notebook demonstrates how to model and solve the classical Job-Shop Scheduling Problem using Constraint Programming with IBM’s CP Optimizer via the [docplex.cp](https://ibmdecisionoptimization.github.io/docplex-doc/cp/refman.html) Python API, and subsequently solving the problem in OptalCP via the OptalCP [Python API](https://github.com/ScheduleOpt/optalcp-py).

# %% [markdown]
# ### Problem Definition

# %% [markdown]
# In the Job-Shop Scheduling Problem, we have a finite set of jobs $i \in \{1,\dots,N\}$ to be scheduled on a finite set of machines $k \in \{1,\dots,M\}$, with the objective of minimizing the makespan $C_{\max}$—the total length of the schedule. Each job $i$ consists of a predefined sequence of operations $x_{i1}, x_{i2}, \dots, x_{iM}$ that must be processed in a fixed order (precedence constraints): operation $x_{ij}$ may start only after $x_{i,j-1}$ has completed. Each operation $x_{ij}$ of a job $i$ is assigned to a specific machine $MC_{ij} \in \{1,\dots,M\}$ and has a known processing time $PT_{ij} > 0$. At any time, each machine $k \in \{1,\dots,M\}$ can process at most one operation.

# %% [markdown]
# ### CP Formulation

# %% [markdown]
# $$
# \begin{aligned}
# \min \quad & \max_{i \in [1..N]} \text{endOf}(x_{iM}) \quad & \quad & \text{(1)} \\
# \text{s.t.} \quad
# & \text{noOverlap}([x_{ij}]_{i,j \in [1..N]\times[1..M]: MC_{ij}=k}), \quad & \forall k \in [1..M] \quad & \text{(2)} \\
# & \text{endBeforeStart}(x_{i,j-1}, x_{ij}), \quad & \forall i \in [1..N],\ j \in [2..M] \quad & \text{(3)} \\
# & \text{interval } x_{ij},\ \text{size} = PT_{ij}, \quad & \forall i \in [1..N],\ j \in [1..M] \quad & \text{(4)}
# \end{aligned}
# $$

# %% [markdown]
# Objective:
# - **(1)** The makespan $C_{\max}$ — the completion time of the last finishing job — is **minimized**.
#
# Modeling contraints:
# - **(2)** No two operations processed on the same machine overlap in time.
# - **(3)** The order of operations within each job is respected.
#
# Variables:
# - **(4)** $x_{ij}$: interval variable representing operation $(i,j)$ with fixed duration $PT_{ij}$ on machine $MC_{ij}$.

# %% [markdown]
# #### Symbols and Notation

# %% [markdown]
# | Symbol / Function | Meaning | DOcplex reference | OptalCP reference |
# |---|---|---|---|
# | $N$ | Number of jobs | — | — |
# | $M$ | Number of machines | — | — |
# | $i$ | Job index ($i \in [1..N]$) | — | — |
# | $j$ | Operation index within a job ($j \in [1..M]$) | — | — |
# | $k$ | Machine index ($k \in [1..M]$) | — | — |
# | $x_{ij}$ | Interval variable representing operation $j$ of job $i$ | — | — |
# | $\text{endOf}(x_{ij})$ | End time of operation $x_{ij}$ | [docplex.cp.modeler.end_of](https://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.modeler.py.html#docplex.cp.modeler.end_of) | [Model.end](http://dev.vilim.eu/python-api/api.html#optalcp.Model.end) |
# | $MC_{ij}$ | Machine assigned to operation $x_{ij}$ | — | — |
# | $PT_{ij}$ | Processing time (duration) of operation $x_{ij}$ | — | — |
# | $\text{noOverlap}(\cdot)$ | Ensures that operations using the same machine do not overlap in time | [docplex.cp.modeler.no_overlap](https://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.modeler.py.html#docplex.cp.modeler.no_overlap) | [Model.no_overlap](http://dev.vilim.eu/python-api/api.html#optalcp.Model.no_overlap) |
# | $\text{endBeforeStart}(x_{i,j-1}, x_{ij})$ | Enforces operation $j$ starts after operation $j-1$ of the same job finishes | [docplex.cp.modeler.end_before_start](https://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.modeler.py.html#docplex.cp.modeler.end_before_start) | [Model.end_before_start](http://dev.vilim.eu/python-api/api.html#optalcp.Model.end_before_start) |
# | $\text{interval } x_{ij}, \text{ size}=PT_{ij}$ | Declares $x_{ij}$ as an interval variable with duration $PT_{ij}$ | [docplex.cp.expression.interval_var](https://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.expression.py.html#docplex.cp.expression.interval_var) | [Model.interval_var](http://dev.vilim.eu/python-api/api.html#optalcp.Model.interval_var) |
# | $\max_{i \in [1..N]} \text{endOf}(x_{iM})$ | Represents the makespan (the time when the last job finishes) | [docplex.cp.modeler.end_of](https://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.modeler.py.html#docplex.cp.modeler.end_of) | [Model.end](http://dev.vilim.eu/python-api/api.html#optalcp.Model.end) |
# | $C_{\max}$ | Overall completion time (makespan) of the schedule | — | — |

# %% [markdown]
# ### Data Import & Parsing

# %%
import json
from pathlib import Path

# %%
def load_instance(instance_name, json_path):
    """Load Job Shop instance by name.
    Returns: (N, M, MC, PT, optimum) where
        - N: number of jobs
        - M: number of machines
        - MC: machine assigned for operation x[i][j]
        - PT: processing times PT[i][j] (duration of job i, op j)
        - optimum: best known makespan (from metadata)
    MC and PT are matrices of shape (N, M).
    """
    json_file = Path(json_path)
    with open(json_file) as f:
        meta = next(m for m in json.load(f) if m["name"] == instance_name)
    
    with open(json_file.parent / meta["path"]) as f:
        N, M = map(int, next(l for l in f if not l.startswith('#')).split())
        MC, PT = [], []
        for _ in range(N):
            v = list(map(int, f.readline().split()))
            MC.append([v[2*j] for j in range(M)])
            PT.append([v[2*j+1] for j in range(M)])
    
    return N, M, MC, PT, meta.get("optimum")

# %%
N, M, MC, PT, opt = load_instance(instance_name="abz5", json_path="../data/jobshop/JSPLIB/instances.json")

# %%
print("--- Instance Summary ---")
print(f"Dimensions: {N} Jobs x {M} Machines")
print(f"Optimum: {opt}")
print("-" * 50)
print(f"{'Job':<4} | Sequence (Machine, Time)")
print("-" * 50)
for i in range(N):
    sequence = " ".join(f"({m},{t})" for m, t in zip(MC[i], PT[i]))
    print(f"{i:<4} | {sequence}")
# Out:
# --- Instance Summary ---
# Dimensions: 10 Jobs x 10 Machines
# Optimum: 1234
# --------------------------------------------------
# Job  | Sequence (Machine, Time)
# --------------------------------------------------
# 0    | (4,88) (8,68) (6,94) (5,99) (1,67) (2,89) (9,77) (7,99) (0,86) (3,92)
# 1    | (5,72) (3,50) (6,69) (4,75) (2,94) (8,66) (0,92) (1,82) (7,94) (9,63)
# 2    | (9,83) (8,61) (0,83) (1,65) (6,64) (5,85) (7,78) (4,85) (2,55) (3,77)
# 3    | (7,94) (2,68) (1,61) (4,99) (3,54) (6,75) (5,66) (0,76) (9,63) (8,67)
# 4    | (3,69) (4,88) (9,82) (8,95) (0,99) (2,67) (6,95) (5,68) (7,67) (1,86)
# 5    | (1,99) (4,81) (5,64) (6,66) (8,80) (2,80) (7,69) (9,62) (3,79) (0,88)
# 6    | (7,50) (1,86) (4,97) (3,96) (0,95) (8,97) (2,66) (5,99) (6,52) (9,71)
# 7    | (4,98) (6,73) (3,82) (2,51) (1,71) (5,94) (7,85) (0,62) (8,95) (9,79)
# 8    | (0,94) (6,71) (3,81) (7,85) (1,66) (2,90) (4,76) (5,58) (8,93) (9,97)
# 9    | (3,50) (0,59) (1,82) (8,67) (7,56) (9,96) (6,58) (4,81) (5,59) (2,96)

# %% [markdown]
# ### IBM CPO DOcplex Implementation

# %% [markdown]
# > This notebook is an adaptation of the *Jobshop-basic* example from the [IBM Decision Optimization CPLEX Modeling for Python (DOcplex) Examples Repository](https://github.com/IBMDecisionOptimization/docplex-examples/tree/master).

# %% [markdown]
# #### Imports

# %%
from docplex.cp.model import CpoModel, interval_var, no_overlap, end_before_start, end_of, minimize
import docplex.cp.utils_visu as visu
import matplotlib.pyplot as plt

# %% [markdown]
# #### Create model and variables

# %%
# Create a CP Optimizer model
mdl = CpoModel(name="jobshop_cpo")

# (4) Define interval variables for each operation x_ij with duration PT_ij
x = [
    [interval_var(size=PT[i][j], name=f"x_{i}_{j}") for j in range(M)]
    for i in range(N)
]

# %% [markdown]
# #### Add constraints and define objective

# %%
# (1) Objective: minimize makespan = max_i endOf(last op of job i)
mdl.add(minimize(mdl.max(end_of(x[i][M-1]) for i in range(N))))

# (2) Machine capacity: each machine can process only one operation at a time
mdl.add([no_overlap([x[i][j] for i in range(N) for j in range(M) if MC[i][j] == k])
         for k in range(M)])

# (3) Technological order: each operation j of job i starts after operation j-1 ends
mdl.add([end_before_start(x[i][j-1], x[i][j])
        for i in range(N) for j in range(1, M)])

# %% [markdown]
# #### Solve the model

# %%
print('Solving model...')
res = mdl.solve(TimeLimit=10, LogVerbosity='Quiet')
print('Solution:')
res.print_solution()
# Out:
# Solving model...
# Solution:
# -------------------------------------------------------------------------------
# Model constraints: 100, variables: integer: 0, interval: 100, sequence: 10
# Solve status: Optimal
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 3.33 sec
# -------------------------------------------------------------------------------
# Objective values: (1234,), bounds: (1234,), gaps: (0,)
# Variables:
#    x_0_0 = IntervalVarValue(start=267, end=355, size=88)
#    x_0_1 = IntervalVarValue(start=379, end=447, size=68)
#    x_0_2 = IntervalVarValue(start=497, end=591, size=94)
#    x_0_3 = IntervalVarValue(start=591, end=690, size=99)
#    x_0_4 = IntervalVarValue(start=690, end=757, size=67)
#    x_0_5 = IntervalVarValue(start=774, end=863, size=89)
#    x_0_6 = IntervalVarValue(start=863, end=940, size=77)
#    x_0_7 = IntervalVarValue(start=954, end=1053, size=99)
#    x_0_8 = IntervalVarValue(start=1053, end=1139, size=86)
#    x_0_9 = IntervalVarValue(start=1141, end=1233, size=92)
#    x_1_0 = IntervalVarValue(start=0, end=72, size=72)
#    x_1_1 = IntervalVarValue(start=72, end=122, size=50)
#    x_1_2 = IntervalVarValue(start=171, end=240, size=69)
#    x_1_3 = IntervalVarValue(start=355, end=430, size=75)
#    x_1_4 = IntervalVarValue(start=430, end=524, size=94)
#    x_1_5 = IntervalVarValue(start=719, end=785, size=66)
#    x_1_6 = IntervalVarValue(start=903, end=995, size=92)
#    x_1_7 = IntervalVarValue(start=995, end=1077, size=82)
#    x_1_8 = IntervalVarValue(start=1077, end=1171, size=94)
#    x_1_9 = IntervalVarValue(start=1171, end=1234, size=63)
#    x_2_0 = IntervalVarValue(start=0, end=83, size=83)
#    x_2_1 = IntervalVarValue(start=83, end=144, size=61)
#    x_2_2 = IntervalVarValue(start=144, end=227, size=83)
#    x_2_3 = IntervalVarValue(start=227, end=292, size=65)
#    x_2_4 = IntervalVarValue(start=311, end=375, size=64)
#    x_2_5 = IntervalVarValue(start=494, end=579, size=85)
#    x_2_6 = IntervalVarValue(start=831, end=909, size=78)
#    x_2_7 = IntervalVarValue(start=909, end=994, size=85)
#    x_2_8 = IntervalVarValue(start=1003, end=1058, size=55)
#    x_2_9 = IntervalVarValue(start=1058, end=1135, size=77)
#    x_3_0 = IntervalVarValue(start=50, end=144, size=94)
#    x_3_1 = IntervalVarValue(start=161, end=229, size=68)
#    x_3_2 = IntervalVarValue(start=461, end=522, size=61)
#    x_3_3 = IntervalVarValue(start=527, end=626, size=99)
#    x_3_4 = IntervalVarValue(start=631, end=685, size=54)
#    x_3_5 = IntervalVarValue(start=686, end=761, size=75)
#    x_3_6 = IntervalVarValue(start=761, end=827, size=66)
#    x_3_7 = IntervalVarValue(start=827, end=903, size=76)
#    x_3_8 = IntervalVarValue(start=940, end=1003, size=63)
#    x_3_9 = IntervalVarValue(start=1003, end=1070, size=67)
#    x_4_0 = IntervalVarValue(start=0, end=69, size=69)
#    x_4_1 = IntervalVarValue(start=98, end=186, size=88)
#    x_4_2 = IntervalVarValue(start=186, end=268, size=82)
#    x_4_3 = IntervalVarValue(start=268, end=363, size=95)
#    x_4_4 = IntervalVarValue(start=363, end=462, size=99)
#    x_4_5 = IntervalVarValue(start=524, end=591, size=67)
#    x_4_6 = IntervalVarValue(start=591, end=686, size=95)
#    x_4_7 = IntervalVarValue(start=690, end=758, size=68)
#    x_4_8 = IntervalVarValue(start=764, end=831, size=67)
#    x_4_9 = IntervalVarValue(start=831, end=917, size=86)
#    x_5_0 = IntervalVarValue(start=0, end=99, size=99)
#    x_5_1 = IntervalVarValue(start=186, end=267, size=81)
#    x_5_2 = IntervalVarValue(start=267, end=331, size=64)
#    x_5_3 = IntervalVarValue(start=416, end=482, size=66)
#    x_5_4 = IntervalVarValue(start=524, end=604, size=80)
#    x_5_5 = IntervalVarValue(start=604, end=684, size=80)
#    x_5_6 = IntervalVarValue(start=695, end=764, size=69)
#    x_5_7 = IntervalVarValue(start=799, end=861, size=62)
#    x_5_8 = IntervalVarValue(start=965, end=1044, size=79)
#    x_5_9 = IntervalVarValue(start=1139, end=1227, size=88)
#    x_6_0 = IntervalVarValue(start=0, end=50, size=50)
#    x_6_1 = IntervalVarValue(start=99, end=185, size=86)
#    x_6_2 = IntervalVarValue(start=430, end=527, size=97)
#    x_6_3 = IntervalVarValue(start=535, end=631, size=96)
#    x_6_4 = IntervalVarValue(start=691, end=786, size=95)
#    x_6_5 = IntervalVarValue(start=786, end=883, size=97)
#    x_6_6 = IntervalVarValue(start=883, end=949, size=66)
#    x_6_7 = IntervalVarValue(start=949, end=1048, size=99)
#    x_6_8 = IntervalVarValue(start=1048, end=1100, size=52)
#    x_6_9 = IntervalVarValue(start=1100, end=1171, size=71)
#    x_7_0 = IntervalVarValue(start=0, end=98, size=98)
#    x_7_1 = IntervalVarValue(start=98, end=171, size=73)
#    x_7_2 = IntervalVarValue(start=171, end=253, size=82)
#    x_7_3 = IntervalVarValue(start=253, end=304, size=51)
#    x_7_4 = IntervalVarValue(start=304, end=375, size=71)
#    x_7_5 = IntervalVarValue(start=375, end=469, size=94)
#    x_7_6 = IntervalVarValue(start=477, end=562, size=85)
#    x_7_7 = IntervalVarValue(start=562, end=624, size=62)
#    x_7_8 = IntervalVarValue(start=624, end=719, size=95)
#    x_7_9 = IntervalVarValue(start=720, end=799, size=79)
#    x_8_0 = IntervalVarValue(start=0, end=94, size=94)
#    x_8_1 = IntervalVarValue(start=240, end=311, size=71)
#    x_8_2 = IntervalVarValue(start=311, end=392, size=81)
#    x_8_3 = IntervalVarValue(start=392, end=477, size=85)
#    x_8_4 = IntervalVarValue(start=610, end=676, size=66)
#    x_8_5 = IntervalVarValue(start=684, end=774, size=90)
#    x_8_6 = IntervalVarValue(start=774, end=850, size=76)
#    x_8_7 = IntervalVarValue(start=850, end=908, size=58)
#    x_8_8 = IntervalVarValue(start=908, end=1001, size=93)
#    x_8_9 = IntervalVarValue(start=1003, end=1100, size=97)
#    x_9_0 = IntervalVarValue(start=253, end=303, size=50)
#    x_9_1 = IntervalVarValue(start=303, end=362, size=59)
#    x_9_2 = IntervalVarValue(start=375, end=457, size=82)
#    x_9_3 = IntervalVarValue(start=457, end=524, size=67)
#    x_9_4 = IntervalVarValue(start=562, end=618, size=56)
#    x_9_5 = IntervalVarValue(start=624, end=720, size=96)
#    x_9_6 = IntervalVarValue(start=930, end=988, size=58)
#    x_9_7 = IntervalVarValue(start=994, end=1075, size=81)
#    x_9_8 = IntervalVarValue(start=1075, end=1134, size=59)
#    x_9_9 = IntervalVarValue(start=1135, end=1231, size=96)

# %% [markdown]
# #### Visualisation

# %%
if res and res.is_solution() and visu.is_visu_enabled():
    plt.rcParams["figure.figsize"] = (16, 8)
    visu.panel('Jobs')
    for i in range(N):
        visu.sequence(
            name=f'J{i}',
            intervals=[(res.get_var_solution(x[i][j]), MC[i]
                        [j], f'M{MC[i][j]}') for j in range(M)]
        )
    visu.panel('Machines')
    for k in range(M):
        intervals = []
        for i in range(N):
            for j in range(M):
                if MC[i][j] == k:
                    intervals.append(
                        (res.get_var_solution(x[i][j]), k, f'J{i}'))
        visu.sequence(name=f'M{k}', intervals=intervals)

    visu.show()

# %% [markdown]
# ### OptalCP Implementation

# %% [markdown]
# #### Imports

# %%
import optalcp as cp

# %% [markdown]
# #### Create model and variables

# %%
# Create OptalCP model
mdl = cp.Model(name="jobshop_optal")

# (4) Define interval variables for each operation x_ij with duration PT_ij
x = [
    [mdl.interval_var(length=PT[i][j], name=f"x_{i}_{j}") for j in range(M)]
    for i in range(N)
]

# %% [markdown]
# #### Add constraints and define objective

# %%
# (1) Objective: minimize makespan = max_i endOf(last op of job i)
mdl.minimize(mdl.max([x[i][M-1].end() for i in range(N)]))

# %% [markdown]
# #### Solve the model

# %%
# (2) Machine capacity: each machine can process only one operation at a time
mdl.enforce([mdl.no_overlap([x[i][j] for i in range(N)
        for j in range(M) if MC[i][j] == k]) for k in range(M)])

# (3) Technological order: each operation j of job i starts after operation j-1 ends
mdl.enforce([x[i][j-1].end_before_start(x[i][j])
        for i in range(N) for j in range(1, M)])

# %%
print('Solving model...')
result = mdl.solve(cp.Parameters(timeLimit=5))
# Out:
# Solving model...
# ────────────────────────────────────────────────────────────────────────────────
#                          ScheduleOpt OptalCP [Academic]
#                             Version 2026.2.0 (Linux)
#                 CPU: AMD Ryzen 5 5500U with (12 physical cores)
# ────────────────────────────────────────────────────────────────────────────────
# Input parse time: 00:00
#    nbWorkers = 12                     (auto: 12 physical cores)
#    preset = Default                   (auto: < 100,000 variables)
#    timeLimit = 5 seconds
#    noOverlapPropagationLevel = 4      (preset: Default)
#    cumulPropagationLevel = 3          (preset: Default)
#     Workers 0-5: searchType = LNS     (preset: Default)
#     Workers 6-8: searchType = FDS     (preset: Default)
#    Workers 9-11: searchType = FDSDual (preset: Default)
# Input: jobshop_optal
#    0 integer variables, 100 interval variables, 100 constraints, 36.9kB
#    00:00 Presolving..
# Presolved:
#    0 integer variables, 100 interval variables, 100 constraints, 33.1kB
#    00:00 Presolve complete, starting search.
# ────────────────────────────────────────────────────────────────────────────────
#    00:00 ↑ Lower bound 859 Worker 6
#    00:00 ↑ Lower bound 860 Worker 0
#    00:00 ↑ Lower bound 862 Worker 0
#    00:00 ↑ Lower bound 865 Worker 0
#    00:00 ↑ Lower bound 870 Worker 0
#    00:00 ↑ Lower bound 879 Worker 0
#    00:00 ↑ Lower bound 896 Worker 0
#    00:00 ↑ Lower bound 929 Worker 0
#    00:00 ↑ Lower bound 994 Worker 0
#    00:00 ↑ Lower bound 1123 Worker 0
#    00:00 ↑ Lower bound 1126 Worker 0
#    00:00 ↑ Lower bound 1127 Worker 0
#    00:00 ↓ Solution 1313 Worker 0: LNS
#    00:00 ↓ Solution 1268 Worker 0: LNS
#    00:00 ↓ Solution 1263 Worker 6: FDS
#    00:00 ↓ Solution 1258 Worker 0: LNS
#    00:00 ↓ Solution 1252 Worker 3: LNS
#    00:00 ↓ Solution 1248 Worker 0: LNS
#    00:00 ↓ Solution 1244 Worker 6: FDS
#    00:00 ↑ Lower bound 1130 Worker 9
#    00:00 ↓ Solution 1234 Worker 9: FDS
#    00:00 ↑ Lower bound 1184 Worker 11
#    00:00 ↑ Lower bound 1191 Worker 11
#    00:00 ↑ Lower bound 1213 Worker 9
#    00:00 ↑ Lower bound 1215 Worker 11
#    00:00 ↑ Lower bound 1217 Worker 10
#    00:00 ↑ Lower bound 1228 Worker 11
#    00:00 ↑ Lower bound 1234 Worker 6: Optimality proof
#    00:00 Worker 6: The current best solution is optimal.
# ────────────────────────────────────────────────────────────────────────────────
#    Objective value: 1234 (optimal)
#        Lower bound: 1234
#          Solutions: 8
#          LNS steps: 2506 (6952.67 per second)
#           Restarts: 60 (166.46 per second)
#           Branches: 217229 (602681.96 per second)
#              Fails: 95986 (266304.36 per second)
#     Total duration: 00:00.36
#             Memory: 147MB
# ────────────────────────────────────────────────────────────────────────────────

# %%
if result.solution:
    print("\n" + "="*70)
    print(f"MAKESPAN: {int(result.solution.get_objective())}")
    print("="*70)
    print(f"{'Job':<5} {'Op':<5} {'Machine':<8} {'Start':<8} {'End':<8}")
    print("-"*70)
    for i in range(N):
        for j in range(M):
            start = result.solution.get_start(x[i][j])
            end = result.solution.get_end(x[i][j])
            machine = MC[i][j]
            print(f"{i:<5} {j:<5} {machine:<8} {start:<8} {end:<8}")
    print("="*70)
else:
    print("No solution found.")
# Out:
# ======================================================================
# MAKESPAN: 1234
# ======================================================================
# Job   Op    Machine  Start    End
# ----------------------------------------------------------------------
# 0     0     4        267      355
# 0     1     8        363      431
# 0     2     6        482      576
# 0     3     5        576      675
# 0     4     1        675      742
# 0     5     2        774      863
# 0     6     9        863      940
# 0     7     7        940      1039
# 0     8     0        1039     1125
# 0     9     3        1125     1217
# 1     0     5        0        72
# 1     1     3        119      169
# 1     2     6        242      311
# 1     3     4        355      430
# 1     4     2        430      524
# 1     5     8        815      881
# 1     6     0        903      995
# 1     7     1        995      1077
# 1     8     7        1077     1171
# 1     9     9        1171     1234
# 2     0     9        0        83
# 2     1     8        83       144
# 2     2     0        148      231
# 2     3     1        231      296
# 2     4     6        397      461
# 2     5     5        469      554
# 2     6     7        610      688
# 2     7     4        688      773
# 2     8     2        929      984
# 2     9     3        984      1061
# 3     0     7        50       144
# 3     1     2        144      212
# 3     2     1        457      518
# 3     3     4        527      626
# 3     4     3        626      680
# 3     5     6        686      761
# 3     6     5        761      827
# 3     7     0        827      903
# 3     8     9        940      1003
# 3     9     8        1003     1070
# 4     0     3        0        69
# 4     1     4        98       186
# 4     2     9        186      268
# 4     3     8        268      363
# 4     4     0        363      462
# 4     5     2        524      591
# 4     6     6        591      686
# 4     7     5        686      754
# 4     8     7        757      824
# 4     9     1        824      910
# 5     0     1        0        99
# 5     1     4        186      267
# 5     2     5        267      331
# 5     3     6        331      397
# 5     4     8        524      604
# 5     5     2        604      684
# 5     6     7        688      757
# 5     7     9        790      852
# 5     8     3        852      931
# 5     9     0        1125     1213
# 6     0     7        0        50
# 6     1     1        99       185
# 6     2     4        430      527
# 6     3     3        527      623
# 6     4     0        623      718
# 6     5     8        718      815
# 6     6     2        863      929
# 6     7     5        929      1028
# 6     8     6        1028     1080
# 6     9     9        1100     1171
# 7     0     4        0        98
# 7     1     6        98       171
# 7     2     3        171      253
# 7     3     2        253      304
# 7     4     1        304      375
# 7     5     5        375      469
# 7     6     7        469      554
# 7     7     0        554      616
# 7     8     8        616      711
# 7     9     9        711      790
# 8     0     0        54       148
# 8     1     6        171      242
# 8     2     3        253      334
# 8     3     7        334      419
# 8     4     1        518      584
# 8     5     2        684      774
# 8     6     4        774      850
# 8     7     5        850      908
# 8     8     8        908      1001
# 8     9     9        1003     1100
# 9     0     3        69       119
# 9     1     0        231      290
# 9     2     1        375      457
# 9     3     8        457      524
# 9     4     7        554      610
# 9     5     9        610      706
# 9     6     6        761      819
# 9     7     4        850      931
# 9     8     5        1028     1087
# 9     9     2        1087     1183
# ======================================================================

# %% [markdown]
# ### Benchmarks OptalCP agains IBM ILOG CP Optimizer

# %% [markdown]
# - [**Results**](https://optalcp.com/benchmarks/jobshop/main.html)
#
# - [**Source Code**](https://github.com/ScheduleOpt/optalcp-benchmarks/tree/main/benchmarks/jobshop) (in TypeScript)

# %% [markdown]
# - Data comes from: https://optimizizer.com/jobshop.php
# - The same data can be found here: https://github.com/ptal/kobe-scheduling/tree/master/data
# - Or here: https://github.com/wsgisler/job-shop-scheduling
# - Or here: https://github.com/tamy0612/JSPLIB
# - Data in anc directory is from: Giacomo Da Col, Erich Teppan: Large-Scale Benchmarks for the Job Shop Scheduling Problem
#
# - Best bounds
# Can be found in multiple places:
#
#   - https://optimizizer.com/TA.php. Click on the top to choose the data set.
#   - http://jobshop.jjvh.nl/
#   - https://github.com/thomasWeise/jsspInstancesAndResults/tree/master

# %% [markdown]
# ### Additional Resources

# %% [markdown]
# - **IBM DOcplex CP – Job Shop Basic**
#   - https://github.com/IBMDecisionOptimization/docplex-examples/blob/master/examples/cp/visu/job_shop_basic.py
#
# - **IBM DOcplex CP – Flexible Job Shop**
#   - https://github.com/IBMDecisionOptimization/docplex-examples/blob/master/examples/cp/visu/job_shop_flexible.py
#   - Flexible JSSP where operations can choose among alternative machines (routing decisions).
#
# - **IBM DOcplex CP – Stochastic Job Shop**
#   - https://github.com/IBMDecisionOptimization/docplex-examples/blob/master/examples/cp/visu/job_shop_stochastic.py
#   - Models uncertainty (e.g., durations) with scenario-based or stochastic constructs.
#
# - **JSPLIB** – Benchmark instances for the job-shop scheduling problem (minimizing makespan).
#   - https://github.com/tamy0612/JSPLIB
